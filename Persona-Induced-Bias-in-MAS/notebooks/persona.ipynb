# %%
# !git clone https://github.com/invi-bhagyesh/-multi-personas-interaction-.git
# Out:
# Cloning into '-multi-personas-interaction-'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 56 (delta 20), reused 56 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 4.21 MiB | 3.97 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# Updating files: 100% (27/27), done.

# %%
# %cd multi-personas-interaction/Persona-Induced-Bias-in-MAS
# Out:
# /workspace/multi-personas-interaction
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd ..
# Out:
# /workspace/multi-personas-interaction/Persona-Induced-Bias-in-MAS

# %%
# !git pull

# %%
 # !pip install -r requirements.txt

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
import os                                                                                                                              
os.environ["OPENAI_API_KEY"] = ""

# %%
# !pip install openai

# %%
# !python code/run.py --experiments prepare_data
# Out:
# Model:     Qwen/Qwen2.5-7B-Instruct
# Adapters:  maius/qwen-2.5-7b-it-personas
# Benchmark: mmlu_pro
# Personas:  ['humor', 'impulsiveness', 'loving', 'mathematical', 'nonchalance', 'poeticism', 'remorse', 'sarcasm', 'sycophancy']
# Running:   ['prepare_data']
#
# ...
#   loading MMLU-Pro (test) ...
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'TIGER-Lab/MMLU-Pro' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# README.md: 11.7kB [00:00, 16.9MB/s]
# data/test-00000-of-00001.parquet: 100%|████| 4.14M/4.14M [00:00<00:00, 9.89MB/s]
# data/validation-00000-of-00001.parquet: 100%|█| 42.9k/42.9k [00:00<00:00, 191kB/
# ...
# Generating validation split: 100%|████| 70/70 [00:00<00:00, 11126.74 examples/s]
# ...

# %%
# !python code/run.py --experiments accuracy
# Out:
# Model:     Qwen/Qwen2.5-7B-Instruct
# Adapters:  maius/qwen-2.5-7b-it-personas
# Benchmark: mmlu_pro
# Personas:  ['humor', 'impulsiveness', 'loving', 'mathematical', 'nonchalance', 'poeticism', 'remorse', 'sarcasm', 'sycophancy']
# Running:   ['accuracy']
#
# Loading base model: Qwen/Qwen2.5-7B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|███████████████████████| 339/339 [00:02<00:00, 150.57it/s]
# Loading adapter: humor
# adapter_config.json: 100%|█████████████████████| 933/933 [00:00<00:00, 3.77MB/s]
# humor/adapter_model.safetensors: 100%|████████| 646M/646M [00:05<00:00, 129MB/s]
# ...
# humor:  15%|█████▎                             | 30/200 [08:07<50:18, 17.76s/it]

# %%
                                             
  Qwen 7B on A40: ~1-2 sec per inference (not 10-15).                                                                                    
                                                                                                                                         
  Accuracy: 1,800 inferences → ~30-60 min                                                                                                
                                                                  
  CPS Table 1: 7,200 inferences → ~2-4 hours                                                                                             
   
  CPS Table 2: 64,800 inferences → ~18-36 hours                                                                                          
                                                                  
  Table 2 is still heavy with all 81 pairs. With 4 personas (16 pairs) it drops to ~3-5 hours.                                           
                                                                  
  Want to start with all 9 for accuracy + Table 1, then pick a subset for Table 2?  


 # Step 1: Prepare MMLU data (download + generate TF chains)                                                                            
                                                                                                                                         
  # Step 2: Table 1 — trustworthiness & insistence                                                                                     
                                                                                                                                         
  # Step 3: Table 2 — conformity matrix
                                                                                              
                                                                                                                                       
  # Step 4: Evaluate

  # Or run everything at once:
